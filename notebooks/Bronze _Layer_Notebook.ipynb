# %%
spark
# Out:
# StatementMeta(, 09614532-7184-4598-a5b2-94806d4cf6dd, 4, Finished, Available, Finished, False)
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="https://sparkui.fabric.microsoft.com/sparkui/0544a961-d825-40f3-ac1e-5f1f3e22421d/workspaceTypes/datacloud/workspaces/e0a308f0-0c2a-4fda-9973-cb2c1028ced1/activities/09614532-7184-4598-a5b2-94806d4cf6dd/applications/application_1781065397757_0001/jobs?capacityId=652eea38-8ecd-4b1f-9c2b-9afcecdc1870&pbiApi=api.fabric.microsoft.com&artifactId=b3e9e097-27d8-4d14-8445-4da3f1e5afdf">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.5.5.4.20260403.6</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Brazil_PySpark_Notebook_09614532-7184-4598-a5b2-94806d4cf6dd</code></dd>
# ...

# %%
customers_df = spark.read.csv(
    "Files/archive/olist_customers_dataset.csv",
    header=True,
    inferSchema=True
)

display(customers_df)
# Out:
# StatementMeta(, 09614532-7184-4598-a5b2-94806d4cf6dd, 5, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, ba2920c7-4dcb-428b-b010-b6b56f22aef5)

# %%
customers_df.show(5)
# Out:
# StatementMeta(, 09614532-7184-4598-a5b2-94806d4cf6dd, 6, Finished, Available, Finished, False)
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |         customer_id|  customer_unique_id|customer_zip_code_prefix|       customer_city|customer_state|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |06b8999e2fba1a1fb...|861eff4711a542e4b...|                   14409|              franca|            SP|
# |18955e83d337fd6b2...|290c77bc529b7ac93...|                    9790|sao bernardo do c...|            SP|
# |4e7b3e00288586ebd...|060e732b5b29e8181...|                    1151|           sao paulo|            SP|
# |b2b6027bc5c5109e5...|259dac757896d24d7...|                    8775|     mogi das cruzes|            SP|
# |4f2d8ab171c80ec83...|345ecd01c38d18a90...|                   13056|            campinas|            SP|
# ...

# %%
customers_df.columns
# Out:
# StatementMeta(, 09614532-7184-4598-a5b2-94806d4cf6dd, 7, Finished, Available, Finished, False)
# ['customer_id',
#  'customer_unique_id',
#  'customer_zip_code_prefix',
#  'customer_city',
#  'customer_state']

# %%
customers_df.printSchema()
# Out:
# StatementMeta(, 09614532-7184-4598-a5b2-94806d4cf6dd, 8, Finished, Available, Finished, False)
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: integer (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)

# %%
customers_df.count()
# Out:
# StatementMeta(, 09614532-7184-4598-a5b2-94806d4cf6dd, 9, Finished, Available, Finished, False)
# 99441

# %%
customers_df.filter(
    customers_df.customer_state == "SP"
).show()
# Out:
# StatementMeta(, 09614532-7184-4598-a5b2-94806d4cf6dd, 10, Finished, Available, Finished, False)
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |         customer_id|  customer_unique_id|customer_zip_code_prefix|       customer_city|customer_state|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |06b8999e2fba1a1fb...|861eff4711a542e4b...|                   14409|              franca|            SP|
# |18955e83d337fd6b2...|290c77bc529b7ac93...|                    9790|sao bernardo do c...|            SP|
# |4e7b3e00288586ebd...|060e732b5b29e8181...|                    1151|           sao paulo|            SP|
# |b2b6027bc5c5109e5...|259dac757896d24d7...|                    8775|     mogi das cruzes|            SP|
# |4f2d8ab171c80ec83...|345ecd01c38d18a90...|                   13056|            campinas|            SP|
# ...

# %%
customers_df.groupBy(
    "customer_state"
).count().show()
# Out:
# StatementMeta(, 09614532-7184-4598-a5b2-94806d4cf6dd, 11, Finished, Available, Finished, False)
# +--------------+-----+
# |customer_state|count|
# +--------------+-----+
# |            SC| 3637|
# |            RO|  253|
# |            PI|  495|
# |            AM|  148|
# |            RR|   46|
# |            GO| 2020|
# |            TO|  280|
# |            MT|  907|
# |            SP|41746|
# |            ES| 2033|
# |            PB|  536|
# |            RS| 5466|
# |            MS|  715|
# |            AL|  413|
# |            MG|11635|
# |            PA|  975|
# |            BA| 3380|
# |            SE|  350|
# |            PE| 1652|
# |            CE| 1336|
# +--------------+-----+
# only showing top 20 rows

# %%
customers_df.write.mode("overwrite") \
.format("delta") \
.saveAsTable("bronze_customers")
# Out:
# StatementMeta(, 09614532-7184-4598-a5b2-94806d4cf6dd, 12, Finished, Available, Finished, False)

# %%
geo_df = spark.read.csv(
    "Files/archive/olist_geolocation_dataset.csv",
    header=True,
    inferSchema=True
)

geo_df.write.mode("overwrite") \
.format("delta") \
.saveAsTable("bronze_geolocation")
# Out:
# StatementMeta(, 09614532-7184-4598-a5b2-94806d4cf6dd, 13, Finished, Available, Finished, False)

# %%
items_df = spark.read.csv(
    "Files/archive/olist_order_items_dataset.csv",
    header=True,
    inferSchema=True
)

items_df.write.mode("overwrite") \
.format("delta") \
.saveAsTable("bronze_order_items")
# Out:
# StatementMeta(, 09614532-7184-4598-a5b2-94806d4cf6dd, 14, Finished, Available, Finished, False)

# %%
payments_df = spark.read.csv(
    "Files/archive/olist_order_payments_dataset.csv",
    header=True,
    inferSchema=True
)

payments_df.write.mode("overwrite") \
.format("delta") \
.saveAsTable("bronze_payments")
# Out:
# StatementMeta(, 09614532-7184-4598-a5b2-94806d4cf6dd, 15, Finished, Available, Finished, False)

# %%
reviews_df = spark.read.csv(
    "Files/archive/olist_order_reviews_dataset.csv",
    header=True,
    inferSchema=True
)

reviews_df.write.mode("overwrite") \
.format("delta") \
.saveAsTable("bronze_reviews")
# Out:
# StatementMeta(, 09614532-7184-4598-a5b2-94806d4cf6dd, 16, Finished, Available, Finished, False)

# %%
orders_df = spark.read.csv(
    "Files/archive/olist_orders_dataset.csv",
    header=True,
    inferSchema=True
)

orders_df.write.mode("overwrite") \
.format("delta") \
.option("mergeSchema", "true") \
.saveAsTable("bronze_orders")
# Out:
# StatementMeta(, 09614532-7184-4598-a5b2-94806d4cf6dd, 17, Finished, Available, Finished, False)

# %%
products_df = spark.read.csv(
    "Files/archive/olist_products_dataset.csv",
    header=True,
    inferSchema=True
)

products_df.write.mode("overwrite") \
.format("delta") \
.saveAsTable("bronze_products")
# Out:
# StatementMeta(, 09614532-7184-4598-a5b2-94806d4cf6dd, 18, Finished, Available, Finished, False)

# %%
sellers_df = spark.read.csv(
    "Files/archive/olist_sellers_dataset.csv",
    header=True,
    inferSchema=True
)

sellers_df.write.mode("overwrite") \
.format("delta") \
.saveAsTable("bronze_sellers")
# Out:
# StatementMeta(, 09614532-7184-4598-a5b2-94806d4cf6dd, 19, Finished, Available, Finished, False)

# %%
translation_df = spark.read.csv(
    "Files/archive/product_category_name_translation.csv",
    header=True,
    inferSchema=True
)

translation_df.write.mode("overwrite") \
.format("delta") \
.saveAsTable("bronze_product_translation")
# Out:
# StatementMeta(, 09614532-7184-4598-a5b2-94806d4cf6dd, 20, Finished, Available, Finished, False)
